# %%
import numpy as np

# %%
Ads=[10,20,30,40,55]
Sale=[15,25,35,50,65]

# %%
corr=np.corrcoef(Ads,Sale)

# %%
corr_value=corr[0,1]

# %%
corr_value
# Out:
# np.float64(0.9975652555573735)

# %%
Ads=[10,20,30,40,55]
Sale=[5,10,5,6,1]

# %%
corr=np.corrcoef(Ads,Sale)

# %%
corr_value=corr[0,1]

# %%
corr_value
# Out:
# np.float64(-0.6333734012025979)

# %%
vaccine=[100,200,300,400,500]
Result=[50,30,40,50,60]

# %%
corr=np.corrcoef(vaccine,Result)

# %%
corr_value=corr[0,1]

# %%
corr_value
# Out:
# np.float64(0.5547001962252291)
